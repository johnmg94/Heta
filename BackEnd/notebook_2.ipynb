# %%
import requests
params = {
    'subscription': 'fred',
    'query': 'GFDGDPA188S'
}
r = requests.get(r'http://127.0.0.1:8000/get_series', params=params)
print(r.status_code)
print(r.text)
# Out:
# 200
# ...
